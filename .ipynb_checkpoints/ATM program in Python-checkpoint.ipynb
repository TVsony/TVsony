# %% [markdown]
# # ATM program in Python

# %%
account_balance=123000

def display_balance():
    print(f"Your account balance is $ {account_balance: .2f}")
    
def deposit():
    global account_balance
    
    amount=float(input("Enter the amount to deposit: $"))
    
    account_balance +=amount
    print(f"Deposited $ {amount: .2}Successfully.")
    display_balance()
    
def withdraw():
    global account_balance
    
    amount=float(input("Enter the amount to withdraw: "))
    if amount>account_balance:
        print("Your account having insufficient founds.")
        
    else:
        account_balance -=amount
        print(f"Withdrew $ {amount: .2f}Successfully.")
        display_balance()
        

def show_menu():
    print("\n ATM Menu: ")
    print("1.Display Balance")
    print("2.Deposit Money")
    print("3. Withdraw Money")
    print("4.Exit")
    
    
while True:
    show_menu()
    choice=input(("Enter your choice (1/2/3/4):"))
    
    if choice == '1':
        display_balance()
        
    elif choice =='2':
        deposit()
        
    elif choice =='3':
        withdraw()
        
    elif choice =='4':
        print("Thank you for using the ATM.Goodbye!")
        break
        
else:
    print("Invalid choice . Please try again.")
# Out:
#  ATM Menu:
# 1.Display Balance
# 2.Deposit Money
# 3. Withdraw Money
# 4.Exit
# Enter your choice (1/2/3/4):2
# Enter the amount to deposit: $1000
# Deposited $  1e+03Successfully.
# Your account balance is $  124000.00
#
#  ATM Menu:
# 1.Display Balance
# 2.Deposit Money
# 3. Withdraw Money
# 4.Exit
# Enter your choice (1/2/3/4):1
# Your account balance is $  124000.00
#
#  ATM Menu:
# 1.Display Balance
# 2.Deposit Money
# 3. Withdraw Money
# 4.Exit
# Enter your choice (1/2/3/4):4
# Thank you for using the ATM.Goodbye!
